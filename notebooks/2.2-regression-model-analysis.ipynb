# %% [markdown]
# # Model Analysis

# %% [markdown]
# # Step 1. Get the data

# %%
import pandas as pd

# %%
from src.constants import X_TRAIN_PATH, X_TEST_PATH, Y_TRAIN_PATH, Y_TEST_PATH

# save the processed data to their corresponding files
X_train = pd.read_csv(filepath_or_buffer=X_TRAIN_PATH, sep=',')
X_test = pd.read_csv(filepath_or_buffer=X_TEST_PATH, sep=',')

y_train = pd.read_csv(filepath_or_buffer=Y_TRAIN_PATH, sep=',')
y_test = pd.read_csv(filepath_or_buffer=Y_TEST_PATH, sep=',')

# %%
# verify x_train
X_train.head()
# Out:
#         age  sex       bmi  children  smoker  region
# 0  0.472227  0.0 -1.756525  0.734336     1.0     2.0
# 1  0.543313  0.0 -1.033082 -0.911192     1.0     3.0
# 2  0.898745  0.0 -0.943687 -0.911192     1.0     1.0
# 3 -0.025379  0.0  0.622393  3.202629     1.0     1.0
# 4  1.040918  0.0 -1.504893  1.557100     1.0     2.0

# %%
# verify x_test
X_test.head()
# Out:
#         age  sex       bmi  children  smoker  region
# 0  0.458596  0.0 -0.937152  0.822509     1.0     3.0
# 1 -0.187133  0.0 -0.167527 -0.899620     1.0     2.0
# 2  1.821801  0.0 -0.665519 -0.899620     0.0     2.0
# 3  0.530343  1.0 -0.846608  1.683574     1.0     2.0
# 4 -1.406842  1.0  0.134287 -0.899620     0.0     2.0

# %%
# verify y_train
y_train.head()
# Out:
#        charges
# 0   9193.83850
# 1   8534.67180
# 2  27117.99378
# 3   8596.82780
# 4  12475.35130

# %%
# verify y_test
y_test.head()
# Out:
#        charges
# 0   9095.06825
# 1   5272.17580
# 2  29330.98315
# 3   9301.89355
# 4  33750.29180

# %% [markdown]
# # Option 1. Model with all the features

# %% [markdown]
# ## Step 1: Initialization and training of the model

# %%
from sklearn.linear_model import LinearRegression

# model 
model = LinearRegression()
model.fit(X_train, y_train.values.ravel())
# Out:
# LinearRegression()

# %% [markdown]
# ## Step 2: Model prediction

# %%
# make the prediction
y_pred = model.predict(X_test)
y_pred
# Out:
# array([ 9.08521280e+03,  7.15018118e+03,  3.70524385e+04,  9.68311549e+03,
#         2.69807765e+04,  1.06646845e+04,  3.21501279e+02,  1.69364233e+04,
#         1.24433906e+03,  1.14103229e+04,  2.82038566e+04,  9.50203680e+03,
#         5.36910209e+03,  3.84097055e+04,  4.02465877e+04,  3.71255863e+04,
#         1.52204653e+04,  3.59552264e+04,  9.28352376e+03,  3.16040469e+04,
#         3.98746422e+03,  1.01259756e+04,  2.30065276e+03,  6.94188729e+03,
#         1.15049101e+04,  1.29485554e+04,  1.44710990e+04,  6.27222981e+03,
#         1.00632358e+04,  2.22871898e+03,  9.19293985e+03,  1.31801357e+04,
#         4.54983678e+03,  3.68362856e+03,  4.43278487e+03,  1.28903819e+04,
#         1.99443645e+03,  8.82995950e+03,  3.34963031e+04,  3.26217760e+04,
#         3.73397527e+04, -2.79954561e+02,  7.06324600e+03,  7.71927740e+03,
#         4.50310559e+03,  5.10811457e+03,  5.90898894e+03,  4.30343579e+03,
#         1.51072872e+04,  1.12956726e+04,  6.83179075e+03,  2.47593836e+03,
#         1.58538721e+03,  3.18525504e+04,  1.64442755e+04,  1.20851628e+04,
#         1.40916106e+03,  1.26139721e+04,  1.55768120e+03,  8.81576964e+03,
#         2.04580610e+03,  3.40733233e+04,  1.07683577e+04,  2.72289796e+03,
#         2.57958576e+04,  2.64937198e+04,  9.60052506e+03,  2.03657081e+03,
#         1.32373124e+04,  1.22793056e+03,  1.05571237e+04,  1.08261075e+04,
#         1.67213258e+04,  2.69597527e+04,  7.16056664e+03,  5.19139355e+03,
#         5.98159292e+03,  1.34752141e+04,  1.13367769e+04,  8.41432859e+03,
#         5.09498721e+03,  1.22678247e+04,  1.37736396e+04,  3.58042654e+04,
#         4.17251724e+03,  2.89671903e+04, -8.38071624e+02,  2.90443843e+03,
#         1.11999155e+04,  1.57203683e+04,  5.16899240e+03,  7.18520941e+03,
#         3.93494208e+03,  3.13374958e+04,  7.53648235e+03,  1.24335145e+04,
#         5.70215422e+03,  9.46006213e+03,  3.63078812e+04,  4.43607750e+03,
#         9.88334436e+03,  3.10758996e+04,  5.73486465e+03,  4.69708495e+03,
#         1.15974984e+03,  4.87361183e+03,  4.60986180e+03,  6.47276142e+03,
#         1.86447819e+04, -1.31954449e+03,  2.32113504e+03,  1.06624416e+04,
#         3.17236992e+03,  1.03599542e+04,  3.76602110e+03,  5.18190932e+03,
#         1.24546955e+04,  6.23674876e+03,  8.35741066e+03,  7.61191153e+03,
#         9.09408937e+03,  1.07591559e+04,  2.78925885e+04,  3.91465296e+04,
#         1.19397628e+04,  7.72366819e+03,  4.07997446e+04,  1.22909779e+04])

# %% [markdown]
# ## Step 3: Metrics

# %% [markdown]
# Let's print the full report of the model

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2  = r2_score(y_test, y_pred)

print(f"MSE: {mse}")
print(f"RMSE: {mse**0.5}")
print(f"Coefficient of determination: {r2}")
# Out:
# MSE: 33624835.693370104
# RMSE: 5798.692584830662
# Coefficient of determination: 0.7834131372909037

# %% [markdown]
# We can see that the error is big, with a slippage of 33 millions and a coverage of 78% of the data. This model cannot be optimized. Let's try with different, the ones that had the best correlation.

# %% [markdown]
# # Option 2. Model with the selected params

# %% [markdown]
# ## Step 1: Modify the params

# %%
# selected columns
selected_features = ['age', 'bmi', 'smoker']

# %%
# update the selected features
X_train = X_train[selected_features]
X_test = X_test[selected_features]

# %%
X_train.head()
# Out:
#         age       bmi  smoker
# 0  0.472227 -1.756525     1.0
# 1  0.543313 -1.033082     1.0
# 2  0.898745 -0.943687     1.0
# 3 -0.025379  0.622393     1.0
# 4  1.040918 -1.504893     1.0

# %%
X_test.head()
# Out:
#         age       bmi  smoker
# 0  0.458596 -0.937152     1.0
# 1 -0.187133 -0.167527     1.0
# 2  1.821801 -0.665519     0.0
# 3  0.530343 -0.846608     1.0
# 4 -1.406842  0.134287     0.0

# %% [markdown]
# ## Step 2: Initialization and training of the model

# %%
from sklearn.linear_model import LinearRegression

# model 
model = LinearRegression()
model.fit(X_train, y_train.values.ravel())
# Out:
# LinearRegression()

# %% [markdown]
# ## Step 3: Model prediction

# %%
# make the prediction
y_pred = model.predict(X_test)
y_pred
# Out:
# array([ 8303.76487684,  7465.01383403, 37489.41821759,  8744.13574931,
#        27284.55314151, 10975.92192054,   663.14230306, 17265.97084616,
#         1382.86146742, 10452.10197172, 27809.02851793,  8952.67692567,
#         5497.55848276, 37620.88744272, 40838.47445666, 36814.55600926,
#        14834.35454962, 36090.96748496,  9466.15806469, 31991.13406696,
#         2667.92050461, 10105.93902393,  3133.05378103,  6864.56193719,
#        10535.37720883, 13011.05196947, 15340.03541891,  5227.63821936,
#         9273.78053063,  2789.78786203,  8286.7719677 , 13528.69940732,
#         5056.8906714 ,  2739.73072619,  4840.51845041, 12886.4921974 ,
#         2403.73274897,  9260.18620332, 33484.56044128, 32762.97812911,
#         2569.21856729,  4216.10264154, 14512.01244954, 12058.56155276,
#         8474.42010006, 12697.574795  ,  4668.47085749,  2793.21721877,
#        34836.93568742,  8777.73230396, 16501.39472578,  2548.59168726,
#        12083.26240688,  1532.12209361, 14082.87120352, 11785.21193262,
#         4465.69296381, 31200.13700897, 14189.90573851, 12927.77673236,
#        15091.80669143,  9997.54289416, 15915.10025912,  7458.77977324,
#        11922.00443722,  4090.83670229, 25859.83534584, 10520.24744751,
#         2234.08063181,  6769.02319264, 10190.74969505, 10797.43565268,
#        11643.72080124,  8977.20394056, 12078.06222707,  7433.68965549,
#         5912.07152048, 11332.60832762,  6303.88991622,  8468.21681418,
#         4312.67526707, 36906.25616877,  6348.80842207, 29819.74384138,
#        34541.59759247, 35371.30987043,  6379.60027267, 13302.63299388,
#         9506.08100487, 13977.13671349, 16801.8406758 , 36269.34146341,
#        32800.36252922,  5411.94931972, 32149.79194671,  9456.99620018,
#        29751.65991542,  4209.30547789, 27575.6633878 ,  5149.89087587,
#         5388.19002184,  2663.19110291, 11981.72499059, 14605.98498516,
#        12016.80623968,  4374.79129621,  9769.47026859, 32734.61252919,
#           73.98158252, 33354.83126431,  3978.80660164, 10018.40516325,
#        13969.07027979, 31211.89896338, 11106.77730323,  4209.30547789,
#        13302.39760482, 31933.18433666,  7971.16548144,  3228.09097255,
#         7953.13869132, 10083.479771  , 14272.88403673,  6152.46920333,
#         3436.16137079,  9726.38413564, 11058.19405158, 10809.19760709,
#        15109.53654266,  7785.75895027,  6076.28806877,  8550.1304565 ,
#         9032.52280604, 12410.36468357,  9121.29516185, 15704.69593494,
#         8316.23299843, 32705.05917373, 36032.21926274, 31640.27249239,
#         6483.00083677, 12612.43641008,  6538.28892733, 14005.0623102 ,
#         3244.28538976, 33159.55670146,  5876.07949008,  5867.71611749,
#        13386.14362004,  7353.54683624, 37733.95142435,  3466.15472946,
#         6235.44750155, 31223.89630685, 11291.79457077,  8399.50823553,
#        14927.08859012, 10141.46027622, 27657.31086615, 33050.65901866,
#        13790.52246211,  1674.91326994, 13411.53067668,  2335.35188413,
#         4900.80210664, 11278.76334632, 40615.30507201, 36995.76546668,
#        33651.58169361,  4672.66793124,  8137.24517754,  9027.32262622,
#        12208.29295707,  4876.30586667,  2884.82505355, 32576.39465265,
#        25962.67280708, 18072.56844359, 26254.31538131, 10820.72417244,
#        37495.41688932,  -598.68976419,  7071.69077919,  8094.09749476,
#         3281.37285098,  5364.66611302,  5513.22057203,  5167.35456313,
#        15137.66675352, 11695.70263472,  6279.06596245,  2484.37712126,
#         1656.91725474, 31798.42881911, 17032.07338808, 12670.38614038,
#         1288.05966496, 11820.73318491,  1591.63803283,  9746.0079096 ,
#         2406.62977776, 34496.33140816, 10342.10885811,  2151.04078377,
#        25955.10792641, 27133.19397845,  9999.73375578,  1061.75786246,
#        13780.02977774,  1696.87096983, 11572.26906837, 11071.31760077,
#        15737.25860861, 27594.95944795,  6930.43503687,  5239.40017377,
#         6131.37154519, 12800.94458419, 12029.06974712,  8515.67386011,
#         5323.146189  , 12535.39523376, 12898.45876595, 35491.61101893,
#         4454.16639846, 29565.78260613,    63.284284  ,  3192.56972026,
#        11395.49207376, 14455.33198927,  5677.10940651,  7642.85548454,
#         3934.48197356, 32277.75030061,  7993.95244817, 13008.15494068,
#         5114.60501264, 10313.97864726, 35953.37648844,  4974.14776224,
#        10088.5368865 , 31024.1892812 ,  5983.58480318,  4815.45910757,
#         1496.36545226,  5174.12095187,  4581.06009646,  6881.31945727,
#        16894.71778062,  -914.03008648,  3144.28340749, 10166.22268016,
#         4048.54906126, 10523.1444763 ,  3579.42332524,  5277.22457708,
#        13397.93634937,  6066.86004029,  8517.83394681,  6304.68840814,
#         8095.6944786 , 11213.3410601 , 28511.45783425, 39797.74401209,
#        12332.38195102,  7363.74258172, 41300.47531523, 12701.71031892])

# %% [markdown]
# ## Step 4: Metrics

# %% [markdown]
# Let's print the full report of the model

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2  = r2_score(y_test, y_pred)

print(f"MSE: {mse}")
print(f"RMSE: {mse**0.5}")
print(f"Coefficient of determination: {r2}")
# Out:
# MSE: 34520308.99137751
# RMSE: 5875.398624040543
# Coefficient of determination: 0.7776451462135991

# %% [markdown]
# We can see that the error is big, with a slippage of 34 millions and a coverage of 77.7% of the data. This model cannot be optimized. We got almost the same result with just 3 features.

# %% [markdown]
# # Conclusion

# %% [markdown]
# With the processing of the data that was made we got result with similar coefficients of determination, this model could be used but the result of using it should be study. Another type of data analysis and processing could end up in better results. Another type of model could get us bette results, like for example Regularized Linear Regression.
